# %%
import matplotlib
# matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
import numpy as np
a=np.linspace(0,10,10)
plt.plot(a)
plt.show(block=False)

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
matplotlib.use('TkAgg')
T = 1/125 #采样周期
fs = 1/T  #sample frequency
# t = np.arange(1,T+1)/T
t = np.arange(0,8,T)
# freqs=np.linspace(0,int(fs/2),len(t)/2)
freqs=np.arange(0,1000)*fs/1000
# freqs = 2*np.pi*(t-0.5-fs)/(fs)
print('t shape:',t.shape)
plt.plot(freqs)
plt.show()
# Out:
# t shape: (1000,)

# %%
import numpy as t
T=1000
t = np.arange(1,T+1)/T
freqs = 2*np.pi*(t-0.5-fs)/(fs)
print(freqs.shape)
# Out:
# (1000,)

# %%
# %run vmd-demo.py

# %%
# %run vmd-demo.py
# Out:
# matplotlib backend: module://ipykernel.pylab.backend_inline
# t shape (1000,)，freqs shape (1000,)
# f shape:(1000,),f type:<class 'numpy.ndarray'>
# len f:1000
# f_hat shape: (1000,)
# type u:<class 'numpy.ndarray'>,type u_hat:<class 'numpy.ndarray'> type omega <class 'numpy.ndarray'>
# u shape:(7, 1000),u_hat shape:(1000, 7),omege shape:(499, 7)
# omega shape: (499, 7)
